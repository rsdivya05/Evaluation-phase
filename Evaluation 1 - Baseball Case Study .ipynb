# %% [markdown]
# # First Phase Evaluation Project - Baseball Case Study

# %% [markdown]
# # Project Description
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features-
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
#
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
#
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
#
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
#
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
#
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
#
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
# -- Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics:
#     https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.
#
# Dataset Link-
# •	https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 17)

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#Now we will check the null values present in the dataset
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Therefore, after checking the null values there are no such missing values present.
# Now we can follow few steps that includes feature engineering, outliers, EDA and model building to analyse.

# %%
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
df_visualization=df[['W']].copy()

# %%
plt.scatter(df["W"],df["R"])
plt.show()

# %%
float_columns = ['W','R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']

for col in float_columns:        # Now, creating a histogram for each column
    plt.figure(figsize=(5, 6))
    plt.hist(df[col], bins=25)
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
float_columns = ['W','R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']
plt.subplots(figsize=(20, 15))
for i, column in enumerate(float_columns):
    plt.subplot(6,3, i + 1)
    sns.distplot(df[column])
plt.show()

# %%
#Lets check the correlation of the columns with targeted columns

plt.figure(figsize=(20,5))
sns.heatmap(df.describe(),annot=True)
plt.show()

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Based on the +/-0.5 skewness range, here are some of columns of the dataset that do not fall within the range: R, H, HR, CG, SHO, SV, E.
#
# Therefore, no skewness in any of the columns, so they will not be treated.

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
plt.figure(figsize=(20,5))
sns.heatmap(df.corr(),annot=True)     #checking whether columns are positive or negative correlated
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,5))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar', grid=True)
plt.xlabel('Attribute',fontsize=14)
plt.ylabel('column with target variable',fontsize=10)
plt.title('correlation',fontsize=14)
plt.show()

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# # Checking of outliers

# %%
# Now we will check for the outliers present in the columns or not.

# %%
for col in float_columns:
    plt.figure(figsize=(8, 5))
    plt.boxplot(df[col], vert=True)
    plt.title(col)
    plt.xlabel(col)
    plt.show()

# %%
df.shape
# Out:
# (30, 17)

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
new_df =df[(z<3).all(axis=1)]
new_df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
new_df.shape
# Out:
# (29, 17)

# %%
dataloss=(30-29)/30*100 
dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# Here, we can see that 3% of the data has been removed from the dataset.

# %%
# Spliting the data into input (x) and target variable (y)

x=df.drop('W',axis=1)
y=df['W']

# %%
from sklearn.preprocessing import MinMaxScaler
minmax_s=MinMaxScaler()
from sklearn.linear_model import LinearRegression
Lr=LinearRegression()

# %%
for i in range(0,43):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    Lr.fit(x_train,y_train)
    predicted_train=Lr.predict(x_train)
    predicted_test=Lr.predict(x_test)
    print(f'At random state {i},the training accuracy is:- {r2_score(y_train,predicted_train)}')
    print(f'At random state {i},the testing accuracy is:- {r2_score(y_test,predicted_test)}')
    print('\n')
# Out:
# At random state 0,the training accuracy is:- 0.9609590618835544
# At random state 0,the testing accuracy is:- 0.6629341689506494
#
#
# At random state 1,the training accuracy is:- 0.9715846357165405
# At random state 1,the testing accuracy is:- 0.38417246900755686
#
#
# At random state 2,the training accuracy is:- 0.9898192153844548
# At random state 2,the testing accuracy is:- -2.081998955010629
#
#
# At random state 3,the training accuracy is:- 0.9722553885185528
# At random state 3,the testing accuracy is:- 0.46183789706023537
#
#
# At random state 4,the training accuracy is:- 0.964746149799658
# At random state 4,the testing accuracy is:- 0.4660685292728326
#
#
# At random state 5,the training accuracy is:- 0.9503092887369994
# At random state 5,the testing accuracy is:- 0.7517105066858509
#
#
# At random state 6,the training accuracy is:- 0.9489470045214469
# At random state 6,the testing accuracy is:- 0.8376419521868452
#
#
# At random state 7,the training accuracy is:- 0.9631978535911321
# At random state 7,the testing accuracy is:- -0.2554769415890812
#
#
# At random state 8,the training accuracy is:- 0.9623956064118229
# At random state 8,the testing accuracy is:- 0.5868676500008623
#
#
# At random state 9,the training accuracy is:- 0.955819020647473
# At random state 9,the testing accuracy is:- 0.729044815551584
#
#
# At random state 10,the training accuracy is:- 0.965838048823881
# At random state 10,the testing accuracy is:- -0.22797129199501565
#
#
# At random state 11,the training accuracy is:- 0.9794801537272684
# At random state 11,the testing accuracy is:- 0.24817597656147006
#
#
# At random state 12,the training accuracy is:- 0.9737413001008606
# At random state 12,the testing accuracy is:- -1.1916550064202265
#
#
# At random state 13,the training accuracy is:- 0.9750450815078384
# At random state 13,the testing accuracy is:- 0.6767079843344664
#
#
# At random state 14,the training accuracy is:- 0.9469984720280227
# At random state 14,the testing accuracy is:- 0.7947948235207266
#
#
# At random state 15,the training accuracy is:- 0.9709420941407682
# At random state 15,the testing accuracy is:- 0.08782646885310985
#
#
# At random state 16,the training accuracy is:- 0.9858809375178785
# At random state 16,the testing accuracy is:- 0.21566361427486103
#
#
# At random state 17,the training accuracy is:- 0.974988444196853
# At random state 17,the testing accuracy is:- 0.24298375665126404
#
#
# At random state 18,the training accuracy is:- 0.9619051538791021
# At random state 18,the testing accuracy is:- 0.44692713019864483
#
#
# At random state 19,the training accuracy is:- 0.9495167250254275
# At random state 19,the testing accuracy is:- 0.8381134193356677
#
#
# At random state 20,the training accuracy is:- 0.9648282100620998
# At random state 20,the testing accuracy is:- 0.30103553183444154
#
#
# At random state 21,the training accuracy is:- 0.9632922835126098
# At random state 21,the testing accuracy is:- 0.437484973066275
#
#
# At random state 22,the training accuracy is:- 0.9538756336575571
# At random state 22,the testing accuracy is:- -0.02296826318033851
#
#
# At random state 23,the training accuracy is:- 0.9614513761755267
# At random state 23,the testing accuracy is:- 0.5703263346963277
#
#
# At random state 24,the training accuracy is:- 0.9930550857101428
# At random state 24,the testing accuracy is:- -3.9281386887175573
#
#
# At random state 25,the training accuracy is:- 0.9579610563737946
# At random state 25,the testing accuracy is:- 0.41817130624128784
#
#
# At random state 26,the training accuracy is:- 0.9658277445021989
# At random state 26,the testing accuracy is:- 0.32413360865115093
#
#
# At random state 27,the training accuracy is:- 0.9552740421332103
# At random state 27,the testing accuracy is:- 0.6767959850140941
#
#
# At random state 28,the training accuracy is:- 0.9597644213445622
# At random state 28,the testing accuracy is:- 0.6699377101719333
#
#
# At random state 29,the training accuracy is:- 0.9511213168423277
# At random state 29,the testing accuracy is:- 0.8790507229532972
#
#
# At random state 30,the training accuracy is:- 0.9494811939208995
# At random state 30,the testing accuracy is:- 0.8365092739163087
#
#
# At random state 31,the training accuracy is:- 0.995157214889656
# At random state 31,the testing accuracy is:- 0.2592083827638815
#
#
# At random state 32,the training accuracy is:- 0.9631618129568899
# At random state 32,the testing accuracy is:- 0.24486497945424646
#
#
# At random state 33,the training accuracy is:- 0.9828979279570368
# At random state 33,the testing accuracy is:- 0.7251644237527024
#
#
# At random state 34,the training accuracy is:- 0.9721607076503064
# At random state 34,the testing accuracy is:- 0.7974272428667599
#
#
# At random state 35,the training accuracy is:- 0.980068511522487
# At random state 35,the testing accuracy is:- 0.18097976995377718
#
#
# At random state 36,the training accuracy is:- 0.9577869158330781
# At random state 36,the testing accuracy is:- 0.734203431983758
#
#
# At random state 37,the training accuracy is:- 0.956470837617814
# At random state 37,the testing accuracy is:- 0.5924138149123748
#
#
# At random state 38,the training accuracy is:- 0.9684911861559722
# At random state 38,the testing accuracy is:- 0.23284767333801826
#
#
# At random state 39,the training accuracy is:- 0.9531716157253376
# At random state 39,the testing accuracy is:- 0.8073613092401368
#
#
# At random state 40,the training accuracy is:- 0.9693187478384301
# At random state 40,the testing accuracy is:- 0.4580507723205728
#
#
# At random state 41,the training accuracy is:- 0.9586218982294643
# At random state 41,the testing accuracy is:- 0.7343696065236927
#
#
# At random state 42,the training accuracy is:- 0.9740426384448528
# At random state 42,the testing accuracy is:- 0.7876400316149443

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
Lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predicted_test=Lr.predict(x_test)

# %%
print(Lr.score(x_train,y_train))
Lr_predict=Lr.predict(x_test)
Lr_train=Lr.predict(x_train)
# Out:
# 0.9740426384448528

# %%
print(r2_score(y_test,predicted_test))
# Out:
# 0.7876400316149443

# %%
from sklearn.model_selection import cross_val_score

# %%
#Now we will do the Cross validation of the model
train_accuracy=r2_score(y_train,predicted_train)
test_accuracy=r2_score(y_test,predicted_test)

for a in range(2,10):
    cross_v_score=cross_val_score(Lr,x,y,cv=a)
    cv_mean=cross_v_score.mean()
    print(f'At cross fold {a} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# At cross fold 2 the cv score is -1.0579322058345517 and accuracy score for training is 0.9740426384448528 and accuracy for the testing is 0.7876400316149443
#
#
# At cross fold 3 the cv score is 0.22588460167736849 and accuracy score for training is 0.9740426384448528 and accuracy for the testing is 0.7876400316149443
#
#
# At cross fold 4 the cv score is 0.24952166654369298 and accuracy score for training is 0.9740426384448528 and accuracy for the testing is 0.7876400316149443
#
#
# At cross fold 5 the cv score is 0.040755406674662355 and accuracy score for training is 0.9740426384448528 and accuracy for the testing is 0.7876400316149443
#
#
# At cross fold 6 the cv score is 0.25153530937201674 and accuracy score for training is 0.9740426384448528 and accuracy for the testing is 0.7876400316149443
#
#
# At cross fold 7 the cv score is 0.3890804644290387 and accuracy score for training is 0.9740426384448528 and accuracy for the testing is 0.7876400316149443
#
#
# At cross fold 8 the cv score is 0.3193702210966815 and accuracy score for training is 0.9740426384448528 and accuracy for the testing is 0.7876400316149443
#
#
# At cross fold 9 the cv score is -4.809084120395153 and accuracy score for training is 0.9740426384448528 and accuracy for the testing is 0.7876400316149443

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predicted_test)
plt.plot(y_test,y_test)
plt.xlabel('Actual Wins',fontsize=10)
plt.ylabel('Number of predicted wins (W)',fontsize=10)
plt.title('Linear Regression',fontsize=14)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
Ls=Lasso()

# %%
parameter_grid = {"alpha": [0.001, 0.01, 0.1, 1.0, 10.0], "random_state": list(range(0,10))}
clf= GridSearchCV(Ls,parameter_grid)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.0, 'random_state': 0}

# %%
Ls=Lasso(alpha=0.01,random_state=0)
Ls.fit(x_test,y_test)
Ls_score_test=Ls.score(x_test,y_test)
predicted_Ls=Ls.predict(x_test)
Ls_score_test*100
# Out:
# 99.99999624884181

# %% [markdown]
# Here, we can see the predicted score to check model accuracy of test data.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
parameter_grid={'criterion': ['mse','mae'], 'max_features':['none','sqrt','log2']}
Rf=RandomForestRegressor()
clf= GridSearchCV(Rf,parameter_grid)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
from sklearn.model_selection import cross_val_score

# %%
Rf=RandomForestRegressor(criterion='mse',max_features='sqrt')
Rf.fit(x_train, y_train)
Rf.score(x_train, y_train)
predicted_decision= Rf.predict(x_test)
Rf_score= r2_score(y_test, predicted_decision)
print('R2 score:', Rf_score*100)
Rfscore=cross_val_score(Rf,x,y,cv=7)
Rfc= Rfscore.mean()
print('Cross validation score:', Rfc*100)
# Out:
# R2 score: 61.54013932868905
# Cross validation score: 6.097987431809731

# %%
import joblib
joblib.dump(Rf, "Baseball_prediction.pkl")
# Out:
# ['Baseball_prediction.pkl']

# %%
new_Rf = joblib.load(open('Baseball_prediction.pkl','rb'))
result=new_Rf.score(x_test,y_test)
print(result*100)
# Out:
# 61.54013932868905

# %%
# Converting the predicted data to a DataFrame
new_Data = pd.DataFrame([new_Rf.predict(x_test)[:],predicted_decision[:]],index=['Predicted','Original'])
new_Data
# Out:
#                0      1      2      3      4      5
# Predicted  79.27  86.93  72.67  88.19  84.37  76.03
# Original   79.27  86.93  72.67  88.19  84.37  76.03
